# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import platform 
from matplotlib import font_manager, rc 

#매킨토시의경우
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') 

#윈도우의경우 
elif platform.system() == 'Windows': 
    font_name= font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name() 
    rc('font', family=font_name)

# %% [markdown]
# dataset1 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset1.csv", encoding = "cp949")
# dataset2 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset2.csv", encoding = "cp949")
# dataset3 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset3.csv", encoding = "cp949")
# dataset4 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset4.csv", encoding = "cp949")
# dataset5 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset5.csv", encoding = "cp949")
# dataset6 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset6.csv", encoding = "cp949")
# dataset7 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset7.csv", encoding = "cp949")
# dataset8 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset8.csv", encoding = "cp949")
# dataset9 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset9.csv", encoding = "cp949")
# dataset10 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset10.csv", encoding = "cp949")
# dataset11 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset11.csv", encoding = "cp949")
# dataset12 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset12.csv", encoding = "cp949")
# dataset13 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset13.csv", encoding = "cp949")
# dataset14 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset14.csv", encoding = "cp949")
# dataset15 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset15.csv", encoding = "cp949")
# dataset16 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset16.csv", encoding = "cp949")
# dataset17 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset17.csv", encoding = "cp949")
# dataset18 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset18.csv", encoding = "cp949")

# %%
data = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\data.csv", encoding = "cp949")
dataset19 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset19.csv", encoding = "cp949")
dataset20 = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\dataset20.csv", encoding = "cp949")

# %%
# 불러온 데이터셋을 하나의 데이터프레임으로 만들기
df = pd.concat([data, dataset19, dataset20], axis = 0)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#         Unnamed: 0  Unnamed: 0.1  assists  champLevel  championId  \
# 0                0           0.0       17          13          43
# 1                1           1.0        9          16         429
# 2                2           2.0        7          16         131
# 3                3           3.0        3          14          78
# 4                4           4.0        9          15         106
# ...            ...           ...      ...         ...         ...
# 163995           5           NaN        9          15         429
# 163996           6           NaN       10          14         517
# ...

# %%
# 솔로 랭크 게임만 불러온다.
df_rank = df.loc[df["queueId"] == 420]
df_rank
# Out:
#         Unnamed: 0  Unnamed: 0.1  assists  champLevel  championId  \
# 0                0           0.0       17          13          43
# 1                1           1.0        9          16         429
# 2                2           2.0        7          16         131
# 3                3           3.0        3          14          78
# 4                4           4.0        9          15         106
# ...            ...           ...      ...         ...         ...
# 163995           5           NaN        9          15         429
# 163996           6           NaN       10          14         517
# 163997           7           NaN        7          15         142
# 163998           8           NaN        7          15         126
# 163999           9           NaN       13          12           9
#
#         combatPlayerScore  damageDealtToObjectives  damageDealtToTurrets  \
# 0                       0                      569                   132
# ...

# %%
print(df_rank.columns); print()    # df_rank의 컬럼 상태
print(df_rank.info())                       # df_rank의 전체적인 정보
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'assists', 'champLevel', 'championId',
#        'combatPlayerScore', 'damageDealtToObjectives', 'damageDealtToTurrets',
#        'damageSelfMitigated', 'deaths',
#        ...
#        'trueDamageDealt', 'trueDamageDealtToChampions', 'trueDamageTaken',
#        'turretKills', 'unrealKills', 'visionScore', 'visionWardsBoughtInGame',
#        'wardsKilled', 'wardsPlaced', 'win'],
#       dtype='object', length=116)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629270 entries, 0 to 163999
# Columns: 116 entries, Unnamed: 0 to win
# dtypes: bool(1), float64(34), int64(72), object(9)
# memory usage: 557.5+ MB
# None

# %%
# 필요없는 컬럼 삭제하기
df_rank.drop(["Unnamed: 0", "Unnamed: 0.1", "firstInhibitorAssist", "firstInhibitorKill", "gameType", "gameMode", "mapId", "name"], axis = 1, inplace = True)
df_rank  # 116개의 컬럼에서 8개를 삭제
# Out:
#         assists  champLevel  championId  combatPlayerScore  \
# 0            17          13          43                  0
# 1             9          16         429                  0
# 2             7          16         131                  0
# 3             3          14          78                  0
# 4             9          15         106                  0
# ...         ...         ...         ...                ...
# 163995        9          15         429                  0
# 163996       10          14         517                  0
# 163997        7          15         142                  0
# 163998        7          15         126                  0
# 163999       13          12           9                  0
#
#         damageDealtToObjectives  damageDealtToTurrets  damageSelfMitigated  \
# 0                           569                   132                15476
# 1                          3602                  3602                18814
# ...

# %%
df_rank.to_csv("C:\\Users\\admin\\Desktop\\lol\\data_rank.csv", encoding = "cp949")

# %% [markdown]
# ## 중복된 데이터 제거하기

# %%
# gameId가 중복되어 있는 데이터들이 있는지 확인한다. value_counts 함수를 통해  중복된 것을 알 수 있다.
df_rank["gameId"].value_counts()
# Out:
# 4317581459    100
# 4307254636     90
# 4308907559     90
# 4319058314     90
# 4319959290     90
#              ...
# 4248978180     10
# 4127357699     10
# 4254986994     10
# 4193026780     10
# 4203753478     10
# Name: gameId, Length: 51458, dtype: int64

# %%
dup = df_rank["gameId"].value_counts() > 10
dup.value_counts()
# Out:
# False    45628
# True      5830
# Name: gameId, dtype: int64

# %%
dup_True = dup.head(5831)
delete = dup_True.index

print(delete)
# Out:
# Int64Index([4317581459, 4307254636, 4308907559, 4319058314, 4319959290,
#             4320761812, 4317275125, 4309428396, 4315221904, 4319518640,
#             ...
#             4211340894, 4287991718, 4263828053, 4314114220, 4251322173,
#             4294585495, 4257053299, 4287909496, 4279113680, 4200860184],
#            dtype='int64', length=5831)

# %%
df_rank.drop(df_rank.loc[df_rank["gameId"] == 4317581459].index[0 : len(df_rank.loc[df_rank["gameId"] == 4317581459])-10], inplace = True)
df_rank.loc[df_rank["gameId"] == 4317581459]
# Out:
#         assists  champLevel  championId  combatPlayerScore  \
# 153490       16          17         145                  0
# 153491       19          15         111                  0
# 153492       23          17         421                  0
# 153493       12          17          62                  0
# 153494       19          18         142                  0
# 153495        8          16         110                  0
# 153496       14          13         223                  0
# 153497        3          16         266                  0
# 153498        4          15          28                  0
# 153499        7          16         134                  0
#
#         damageDealtToObjectives  damageDealtToTurrets  damageSelfMitigated  \
# 153490                    18394                  3870                13614
# 153491                     2021                   376                36030
# 153492                    36269                  2965                24347
# ...

# %%
for num in range(:
    print(len(df_rank.loc[df_rank["gameId"] == num]))
    df_rank.drop(df_rank.loc[df_rank["gameId"] == num].index[0 : len(df_rank.loc[df_rank["gameId"] == num])-10], inplace = True)
    print(len(df_rank.loc[df_rank["gameId"] == num]))
    print()
# Out:
# 10
# 10
#
# 90
# 10
#
# 90
# 10
#
# 90
# 10
#
# 90
# 10
#
# 90
# 10
#
# 90
# 10
#
# 90
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 70
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 70
# 10
#
# 80
# 10
#
# 80
# 10
#
# 80
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 60
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 60
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# 70
# 10
#
# ...

# %%
df_rank["gameId"].value_counts()
# Out:
# 4307058503    20
# 4309823260    20
# 4171009752    20
# 4299062612    20
# 4234856913    20
#               ..
# 4000040412     1
# 4220217245     1
# 3918130296     1
# 3912177962     1
# 4193141432     1
# Name: gameId, Length: 44005, dtype: int64

# %%
df_rank
# Out:
#         assists  champLevel  championId  combatPlayerScore  \
# 580          13          16          81                  0
# 581           8          17          56                  0
# 582          15          15         497                  0
# 583           9          18         102                  0
# 584          14          18          17                  0
# ...         ...         ...         ...                ...
# 163995        9          15         429                  0
# 163996       10          14         517                  0
# 163997        7          15         142                  0
# 163998        7          15         126                  0
# 163999       13          12           9                  0
#
#         damageDealtToObjectives  damageDealtToTurrets  damageSelfMitigated  \
# 580                       18927                  5559                14219
# 581                        5128                  2684                19980
# ...

# %% [markdown]
# 먼저 딥 러닝을 수행하기 전에 컬럼 수를 조정해야 할 필요성이 있다. 우선 승패 컬럼은 따로 출력 레이블로 지정하고, item1 ~ item6는 제거하는 것이 좋을 것 같다. 또한 info함수의 결과를 보면 object형 데이터 컬럼이 존재하기 때문에 검색 후 가능하다면 int나 float으로 변형해야 한다.
# 데이터들을 살펴본 결과 firstInhibitorAssist, firstInhibitorKill, name, gameId, gameMode, gameType, item1,item2, item3, item4, item5, item6, queueId, teamId 컬럼은 삭제하도록 정했다.

# %%
df_rank.columns
# Out:
# Index(['Unnamed: 0', 'assists', 'champLevel', 'championId',
#        'combatPlayerScore', 'damageDealtToObjectives', 'damageDealtToTurrets',
#        'damageSelfMitigated', 'deaths', 'doubleKills',
#        ...
#        'trueDamageDealt', 'trueDamageDealtToChampions', 'trueDamageTaken',
#        'turretKills', 'unrealKills', 'visionScore', 'visionWardsBoughtInGame',
#        'wardsKilled', 'wardsPlaced', 'win'],
#       dtype='object', length=115)

# %%
df_rank.drop(['firstInhibitorAssist', 'firstInhibitorKill', 'name', 'gameId', 'gameMode', 'gameType', 'item1','item2', 'item3', 'item4', 'item5', 'item6', 
              'queueId', 'teamId', 'Unnamed: 0',"participantId"], axis = 1, inplace = True)
df_rank.columns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Index(['Unnamed: 0', 'assists', 'champLevel', 'championId',
#        'combatPlayerScore', 'damageDealtToObjectives', 'damageDealtToTurrets',
#        'damageSelfMitigated', 'deaths', 'doubleKills',
#        ...
#        'trueDamageDealt', 'trueDamageDealtToChampions', 'trueDamageTaken',
#        'turretKills', 'unrealKills', 'visionScore', 'visionWardsBoughtInGame',
#        'wardsKilled', 'wardsPlaced', 'win'],
#       dtype='object', length=101)

# %%
# 승패 결과는 따로 result에 넣는다.
result = df_rank["win"]
df_rank.drop(['win'], axis = 1, inplace = True)

result.to_csv("C:\\Users\\admin\\Desktop\\lol\\result.csv", encoding = "cp949")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'win'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-166-41eb3a3d92c0> in <module>
#       1 # 승패 결과는 따로 result에 넣는다.
# ...

# %%
df_rank.to_csv("C:\\Users\\admin\\Desktop\\lol\\rank_new.csv", encoding = "cp949")

# %% [markdown]
# ## 데이터 변형하기

# %%
# 저장되어 있던 파일 불러오기
df_rank = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\rank_new.csv", encoding = "cp949")
df_rank
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0  assists  champLevel  championId  combatPlayerScore  \
# 0                0       17          13          43                  0
# 1                1        9          16         429                  0
# 2                2        7          16         131                  0
# 3                3        3          14          78                  0
# 4                4        9          15         106                  0
# ...            ...      ...         ...         ...                ...
# 195615        6495        5           9         111                  0
# 195616        6496        4          11         145                  0
# 195617        6497        1          11          82                  0
# ...

# %%
df_rank.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
# 데이터프레임을 한 팀을 하나의 로우로 변경(5개를 1개의 로우로 변경)
# axis = 1 이면 세로로 늘어남
# axis = 0 이면 가로로 늘어남
# 문제는 concat할 때 전치가 일어남

# %%
idx = pd.Index(range(1, 195621))
idx

df_rank.index = idx
df_rank
# Out:
#         assists  champLevel  championId  combatPlayerScore  \
# 1            17          13          43                  0
# 2             9          16         429                  0
# 3             7          16         131                  0
# 4             3          14          78                  0
# 5             9          15         106                  0
# ...         ...         ...         ...                ...
# 195616        5           9         111                  0
# 195617        4          11         145                  0
# 195618        1          11          82                  0
# 195619        6          10           9                  0
# 195620        1          11          17                  0
#
#         damageDealtToObjectives  damageDealtToTurrets  damageSelfMitigated  \
# 1                           569                   132                15476
# 2                          3602                  3602                18814
# ...

# %%
df = pd.DataFrame()
small = pd.DataFrame()   # 빈 데이터프레임

for i in range(len(df_rank)):
    small = pd.concat([small, df_rank.iloc[i]], axis = 0)
    if len(small) == 490:
        df = pd.concat([df, small], axis = 1)
        small = pd.DataFrame()
        
df
# Out:
#                            0     0     0     0     0      0     0     0  \
# assists                   17    15     9    10     3      8     4    11
# champLevel                13    14    11    10    15     16    15    16
# championId                43   235    21    43   236    245   266    55
# combatPlayerScore          0     0     0     0     0      0     0     0
# damageDealtToObjectives  569  7412  1939  1107  7212  22341  4959  5367
# ...                      ...   ...   ...   ...   ...    ...   ...   ...
# unrealKills                0     0     0     0     0      0     0     0
# visionScore               17    22    13    18    18     17    75    22
# visionWardsBoughtInGame    3     4     1     2     5      1    10     1
# wardsKilled                3     3     1     1     2      5    10     4
# wardsPlaced                4    13     7     8    13      7    31     9
#
#                              0     0  ...     0     0     0    0      0    0  \
# ...

# %%
team_data = df.T
team_data.to_csv("C:\\Users\\admin\\Desktop\\lol\\team.csv", encoding = "cp949")

# %%
pick = df_rank["championId"].value_counts().head(20)
pick = pd.DataFrame(pick)
pick.reset_index()
li = pick.index
pick
# Out:
#      championId
# 81         2938
# 64         2295
# 21         2148
# 145        2021
# 51         1861
# 412        1845
# 236        1831
# 86         1430
# 245        1426
# 53         1406
# 517        1399
# 157        1395
# 235        1304
# 67         1296
# 89         1277
# 22         1249
# 516        1230
# 154        1162
# 875        1158
# 111        1156

# %%
champ = pd.read_csv("C:\\Users\\admin\\Desktop\\lol\\champ.csv", encoding = "cp949")
champ.drop("Unnamed: 0", axis = 1, inplace = True)
champ
# Out:
#         name  num
# 0     Aatrox  266
# 1       Ahri  103
# 2      Akali   84
# 3    Alistar   12
# 4      Amumu   32
# ..       ...  ...
# 143      Zed  238
# 144    Ziggs  115
# 145   Zilean   26
# 146      Zoe  142
# 147     Zyra  143
#
# [148 rows x 2 columns]

# %%
for name in range(20):
    print(champ.loc[champ["num"] == li[name]])

name = ["Ezreal", "LeeSin", "MissFortune", "Kaisa", "Caitlyn", "Thresh", "Lucian", "Garen", "Ekko", "Blitzcrank", 
       "Sylas", "Yasuo", "Senna", "Vayne", "Leona", "Ashe", "Ornn", "Zac", "Sett", "Nautilus"]
# Out:
#       name  num
# 27  Ezreal   81
#       name  num
# 62  LeeSin   64
#            name  num
# 72  MissFortune   21
#      name  num
# 48  Kaisa  145
#        name  num
# 15  Caitlyn   51
#        name  num
# 119  Thresh  412
#       name  num
# 65  Lucian  236
#      name  num
# 33  Garen   86
#     name  num
# 24  Ekko  245
#           name  num
# 12  Blitzcrank   53
#       name  num
# 112  Sylas  517
#       name  num
# 139  Yasuo  157
#       name  num
# 100  Senna  235
#       name  num
# 128  Vayne   67
#      name  num
# 63  Leona   89
#    name  num
# 8  Ashe   22
#     name  num
# 85  Ornn  516
#     name  num
# 142  Zac  154
#      name  num
# 101  Sett  875
#         name  num
# 78  Nautilus  111

# %%
pick["name"] = name
pick = pick.rename({"championId" : "counts"}, axis = "columns")
pick
plt.figure(figsize = (20, 10))
plt.bar(pick["name"], pick["counts"])
plt.show()
